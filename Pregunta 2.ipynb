# %%
import tkinter as tk
from PIL import Image, ImageTk
import numpy as np
import cv2


def escalar_imagen(image, max_width):
    original_height, original_width = image.shape
    ratio = max_width / original_width
    height = int(original_height * ratio)
    return cv2.resize(image, (max_width, height))

def aplicar_filtro_gaussiano(image, size):
    return cv2.GaussianBlur(image, (size, size), 0)

def mostrar_imagen(image, label, max_width):
    imagen_resized = escalar_imagen(image, max_width)
    imagen_tk = ImageTk.PhotoImage(image=Image.fromarray(imagen_resized))
    label.config(image=imagen_tk)
    label.image = imagen_tk

def actualizar_filtro(valor):
    size = int(valor)
    imagen_filtrada = aplicar_filtro_gaussiano(img, size)
    
    mostrar_imagen(img, label_imagen, 300)
    mostrar_imagen(imagen_filtrada, label_g_real, 300)
    
    # Muestra la matriz del filtro frecuencial (opcional)
    filtro_frecuencial = np.fft.fftshift(np.fft.fft2(imagen_filtrada))
    filtro_frecuencial_magnitud = np.abs(filtro_frecuencial)
    mostrar_imagen(filtro_frecuencial_magnitud, label_matriz, 300)

# Ruta de la imagen a mostrar
image_path = "scarlet.jpg"
img = cv2.imread(image_path, 0)

ventana = tk.Tk()
ventana.title("Filtro Gaussiano con Tkinter")

label_imagen = tk.Label(ventana)
mostrar_imagen(img, label_imagen, 300)
label_imagen.grid(row=0, column=0, padx=10, pady=10)

label_matriz = tk.Label(ventana)
label_matriz.grid(row=0, column=1, padx=10, pady=10)

label_g_real = tk.Label(ventana)
label_g_real.grid(row=0, column=2, padx=10, pady=10)

slider_n = tk.Scale(ventana, from_=1, to=30, orient=tk.HORIZONTAL,
                    label="Tamaño del filtro", command=actualizar_filtro)
slider_n.set(2)
slider_n.grid(row=1, column=0, columnspan=3, pady=10)

ventana.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
#
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Windows10\.conda\envs\Instalaciones\lib\tkinter\__init__.py", line 1702, in __call__
#     return self.func(*args)
#   File "<ipython-input-10-7d3b513890fa>", line 24, in actualizar_filtro
#     imagen_filtrada = aplicar_filtro_gaussiano(img, size)
#   File "<ipython-input-10-7d3b513890fa>", line 14, in aplicar_filtro_gaussiano
#     return cv2.GaussianBlur(image, (size, size), 0)
# cv2.error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\smooth.cpp:3818: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
